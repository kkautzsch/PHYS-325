# %%
import numpy as np
import matplotlib.pyplot as plt

#Constants
R = 10000 #Ohms
R_L = 33 #Ohms
C = 0.1e-6 #microFarads
L = 10e-3 #milliHenry's

#Functions
def V(w):
    return (np.sqrt((1 + (R*R_L*C)/L)**2 + (R*w*C - R/(w*L))**2))**(-1)

def phi(w):
    return -np.arctan((R*w*C - R/(w*L))/(1 + (R*R_L*C)/L))

w = np.linspace(-250,250,100)

plt.plot(w,V(w))
plt.show()
