# %% [markdown]
# <b>Exercise 1</b> <i>Interpolation</i>

# %%
#Kaleb Kautzsch
#Part (i)

#Import libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = [-4, -3, -2, -1, 0, 1, 2, 3, 4]
y = [1.125e-7, 1.234e-4, 1.832e-2, 3.679e-1, 1, 3.679e-1, 1.832e-2, 1.234e-4, 1.125e-7]

plt.plot(x,y)
plt.xlabel("x",fontsize=16)
plt.title("Brokeback MountainPeak")
plt.show()
