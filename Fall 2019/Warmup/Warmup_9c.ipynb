# %% [markdown]
# # Part (c)

# %%
import numpy.random as npr

#Step (i): Print uniformily between 0 and 1
print(npr.rand(),'Value between 0 and 1')

#Step (ii): Print uniformily between 3 and 5
start = 3
end = 5
interval = end-start
print(start + interval*npr.rand(), 'Value between 3 and 5')

#Step (iii): A random integer between 0 and 5
print(npr.randint(6), 'Integer between 0 and 5 inclusive')
# Out:
# 0.20481277502672812 Value between 0 and 1
# 3.2809065772848998 Value between 3 and 5
# 2 Integer between 0 and 5 inclusive
